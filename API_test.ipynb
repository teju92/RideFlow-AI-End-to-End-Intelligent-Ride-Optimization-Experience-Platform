# %%
import requests

# Test demand endpoint
response = requests.post(
    "http://localhost:8000/predict/demand",
    json={
        "pickup_cluster": 3,
        "hour"          : 18,
        "lag_1h"        : 45,
        "lag_2h"        : 40
    }
)
print("=== Demand Prediction ===")
print(response.json())

# Test feedback endpoint
response2 = requests.post(
    "http://localhost:8000/analyze/feedback",
    json={"feedback_text": "Driver was very rude and cancelled last minute"}
)
print("\n=== Feedback Analysis ===")
print(response2.json())

# Test chat endpoint
response3 = requests.post(
    "http://localhost:8000/chat",
    json={
        "message" : "Where is my driver?",
        "language": "English",
        "role"    : "Customer"
    }
)
print("\n=== Chatbot ===")
print(response3.json())
# Out:
# === Demand Prediction ===
# {'predicted_demand': 24, 'demand_level': 'Low', 'zone': 3, 'hour': 18}
#
# === Feedback Analysis ===
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File D:\Tejashri\anaconda\anaconda3\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File D:\Tejashri\anaconda\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
# ...
